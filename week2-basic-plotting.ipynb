# %%
import pandas as pd

# Read in file, argument is the file path
df = pd.read_csv('data/wetlands_seasonal_bird_diversity.csv')

# %%
# Print data frame's first five rows 
df.head()
# Out:
#    year  CSM_winter  CSM_spring  CSM_fall  MUL_winter  MUL_spring  MUL_fall  \
# 0  2010        39.0        40.0      50.0        45.0         NaN      61.0
# 1  2011        48.0        44.0       NaN        58.0        52.0       NaN
# 2  2012        51.0        43.0      49.0        57.0        58.0      53.0
# 3  2013        42.0        46.0      38.0        60.0        58.0      62.0
# 4  2014        38.0        43.0      45.0        49.0        52.0      57.0
#
#    SDW_winter  SDW_spring  SDW_fall  TJE_winter  TJE_spring  TJE_fall
# 0         NaN        75.0      85.0         NaN         NaN      81.0
# 1        78.0        74.0       NaN        67.0        70.0       NaN
# 2        71.0        72.0      73.0        70.0        63.0      69.0
# 3        69.0        70.0      70.0        69.0        74.0      64.0
# 4        61.0        78.0      71.0        60.0        81.0      62.0

# %%
# Print data frame's last five rows 
df.tail()
# Out:
#     year  CSM_winter  CSM_spring  CSM_fall  MUL_winter  MUL_spring  MUL_fall  \
# 9   2019        39.0        39.0      40.0        57.0        52.0      53.0
# 10  2020        46.0         NaN      47.0        56.0         NaN      66.0
# 11  2021        47.0        44.0      53.0        54.0        55.0      60.0
# 12  2022        40.0        46.0      49.0        60.0        55.0      65.0
# 13  2023        56.0        43.0      36.0        72.0        59.0      53.0
#
#     SDW_winter  SDW_spring  SDW_fall  TJE_winter  TJE_spring  TJE_fall
# 9         54.0        55.0      53.0        63.0        54.0      50.0
# 10        57.0         NaN      58.0        54.0        40.0      54.0
# 11        57.0        58.0      57.0        53.0        68.0      51.0
# 12        57.0        60.0      57.0        60.0        61.0      60.0
# 13        64.0        63.0      33.0        60.0        56.0      38.0

# %%
# Print data frame's column names
df.columns
# Out:
# Index(['year', 'CSM_winter', 'CSM_spring', 'CSM_fall', 'MUL_winter',
#        'MUL_spring', 'MUL_fall', 'SDW_winter', 'SDW_spring', 'SDW_fall',
#        'TJE_winter', 'TJE_spring', 'TJE_fall'],
#       dtype='object')

# %%
# List the data types of each column
df.dtypes
# Out:
# year            int64
# CSM_winter    float64
# CSM_spring    float64
# CSM_fall      float64
# MUL_winter    float64
# MUL_spring    float64
# MUL_fall      float64
# SDW_winter    float64
# SDW_spring    float64
# SDW_fall      float64
# TJE_winter    float64
# TJE_spring    float64
# TJE_fall      float64
# dtype: object

# %%
# Print data frame's shape: output is a tuple (# rows, # columns)
df.shape
# Out:
# (14, 13)

# %%
df['MUL_winter']
# Out:
# 0     45.0
# 1     58.0
# 2     57.0
# 3     60.0
# 4     49.0
# 5     58.0
# 6     63.0
# 7     57.0
# 8     56.0
# 9     57.0
# 10    56.0
# 11    54.0
# 12    60.0
# 13    72.0
# Name: MUL_winter, dtype: float64

# %%
# Select a single column by using square brackets []
mul_spring = df['MUL_spring']

# Print first five elements in this column
mul_spring.head()
# Out:
# 0     NaN
# 1    52.0
# 2    58.0
# 3    58.0
# 4    52.0
# Name: MUL_spring, dtype: float64

# %%
# Check the type of the ouput
print(type(mul_spring))
# Out:
# <class 'pandas.core.series.Series'>

# %%
df.MUL_winter
# Out:
# 0     45.0
# 1     58.0
# 2     57.0
# 3     60.0
# 4     49.0
# 5     58.0
# 6     63.0
# 7     57.0
# 8     56.0
# 9     57.0
# 10    56.0
# 11    54.0
# 12    60.0
# 13    72.0
# Name: MUL_winter, dtype: float64

# %%
df.MUL_spring.head()
# Out:
# 0     NaN
# 1    52.0
# 2    58.0
# 3    58.0
# 4    52.0
# Name: MUL_spring, dtype: float64

# %%
df[['MUL_winter', 'MUL_fall', 'MUL_spring']]
# Out:
#     MUL_winter  MUL_fall  MUL_spring
# 0         45.0      61.0         NaN
# 1         58.0       NaN        52.0
# 2         57.0      53.0        58.0
# 3         60.0      62.0        58.0
# 4         49.0      57.0        52.0
# 5         58.0      51.0        50.0
# 6         63.0      58.0        48.0
# 7         57.0      53.0        54.0
# 8         56.0      57.0        54.0
# 9         57.0      53.0        52.0
# 10        56.0      66.0         NaN
# 11        54.0      60.0        55.0
# 12        60.0      65.0        55.0
# 13        72.0      53.0        59.0

# %%
# Print data frame's shape: output is a tuple (# rows, # columns)
df.shape
# Out:
# (14, 13)

# %%
# Select columns with names "TJE_winter" and "TJE_fall"
tje_wf = df[['TJE_winter','TJE_fall']]

# %%
df.loc[ : , 'MUL_winter':'TJE_winter']
# Out:
#     MUL_winter  MUL_spring  MUL_fall  SDW_winter  SDW_spring  SDW_fall  \
# 0         45.0         NaN      61.0         NaN        75.0      85.0
# 1         58.0        52.0       NaN        78.0        74.0       NaN
# 2         57.0        58.0      53.0        71.0        72.0      73.0
# 3         60.0        58.0      62.0        69.0        70.0      70.0
# 4         49.0        52.0      57.0        61.0        78.0      71.0
# 5         58.0        50.0      51.0        71.0        61.0      65.0
# 6         63.0        48.0      58.0        67.0        62.0      57.0
# 7         57.0        54.0      53.0        66.0        45.0      54.0
# 8         56.0        54.0      57.0        55.0        49.0      51.0
# 9         57.0        52.0      53.0        54.0        55.0      53.0
# 10        56.0         NaN      66.0        57.0         NaN      58.0
# 11        54.0        55.0      60.0        57.0        58.0      57.0
# 12        60.0        55.0      65.0        57.0        60.0      57.0
# 13        72.0        59.0      53.0        64.0        63.0      33.0
#
#     TJE_winter
# 0          NaN
# 1         67.0
# 2         70.0
# 3         69.0
# 4         60.0
# 5         73.0
# 6         76.0
# 7         72.0
# 8         66.0
# 9         63.0
# 10        54.0
# 11        53.0
# 12        60.0
# 13        60.0

# %%
# Select columns between 'CSM_winter' and 'MUL_fall'
csm_mul = df.loc[:,'CSM_winter':'MUL_fall']
csm_mul.head()
# Out:
#    CSM_winter  CSM_spring  CSM_fall  MUL_winter  MUL_spring  MUL_fall
# 0        39.0        40.0      50.0        45.0         NaN      61.0
# 1        48.0        44.0       NaN        58.0        52.0       NaN
# 2        51.0        43.0      49.0        57.0        58.0      53.0
# 3        42.0        46.0      38.0        60.0        58.0      62.0
# 4        38.0        43.0      45.0        49.0        52.0      57.0

# %%
df[df['year']<2020]
# Out:
#    year  CSM_winter  CSM_spring  CSM_fall  MUL_winter  MUL_spring  MUL_fall  \
# 0  2010        39.0        40.0      50.0        45.0         NaN      61.0
# 1  2011        48.0        44.0       NaN        58.0        52.0       NaN
# 2  2012        51.0        43.0      49.0        57.0        58.0      53.0
# 3  2013        42.0        46.0      38.0        60.0        58.0      62.0
# 4  2014        38.0        43.0      45.0        49.0        52.0      57.0
# 5  2015        44.0        42.0      45.0        58.0        50.0      51.0
# 6  2016        41.0        36.0      47.0        63.0        48.0      58.0
# 7  2017        46.0        41.0      43.0        57.0        54.0      53.0
# 8  2018        48.0        48.0      44.0        56.0        54.0      57.0
# 9  2019        39.0        39.0      40.0        57.0        52.0      53.0
#
#    SDW_winter  SDW_spring  SDW_fall  TJE_winter  TJE_spring  TJE_fall
# 0         NaN        75.0      85.0         NaN         NaN      81.0
# 1        78.0        74.0       NaN        67.0        70.0       NaN
# 2        71.0        72.0      73.0        70.0        63.0      69.0
# 3        69.0        70.0      70.0        69.0        74.0      64.0
# 4        61.0        78.0      71.0        60.0        81.0      62.0
# 5        71.0        61.0      65.0        73.0        76.0      64.0
# 6        67.0        62.0      57.0        76.0        76.0      58.0
# 7        66.0        45.0      54.0        72.0        63.0      57.0
# 8        55.0        49.0      51.0        66.0        60.0      55.0
# 9        54.0        55.0      53.0        63.0        54.0      50.0

# %%
# Select all rows with year > 2020
post_2020 = df[df['year']>2020]
post_2020
# Out:
#     year  CSM_winter  CSM_spring  CSM_fall  MUL_winter  MUL_spring  MUL_fall  \
# 11  2021        47.0        44.0      53.0        54.0        55.0      60.0
# 12  2022        40.0        46.0      49.0        60.0        55.0      65.0
# 13  2023        56.0        43.0      36.0        72.0        59.0      53.0
#
#     SDW_winter  SDW_spring  SDW_fall  TJE_winter  TJE_spring  TJE_fall
# 11        57.0        58.0      57.0        53.0        68.0      51.0
# 12        57.0        60.0      57.0        60.0        61.0      60.0
# 13        64.0        63.0      33.0        60.0        56.0      38.0

# %%
# Check the type of df['year']>1996
print(type(df['year']>2020))

# Print the boolean series
df['year']>2020
# Out:
# <class 'pandas.core.series.Series'>
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11     True
# 12     True
# 13     True
# Name: year, dtype: bool

# %%
subset = df[df['year'].between(2012, 2015)]
subset
# Out:
#    year  CSM_winter  CSM_spring  CSM_fall  MUL_winter  MUL_spring  MUL_fall  \
# 2  2012        51.0        43.0      49.0        57.0        58.0      53.0
# 3  2013        42.0        46.0      38.0        60.0        58.0      62.0
# 4  2014        38.0        43.0      45.0        49.0        52.0      57.0
# 5  2015        44.0        42.0      45.0        58.0        50.0      51.0
#
#    SDW_winter  SDW_spring  SDW_fall  TJE_winter  TJE_spring  TJE_fall
# 2        71.0        72.0      73.0        70.0        63.0      69.0
# 3        69.0        70.0      70.0        69.0        74.0      64.0
# 4        61.0        78.0      71.0        60.0        81.0      62.0
# 5        71.0        61.0      65.0        73.0        76.0      64.0

# %%
# Avoid this
# Select rows with year<2015 using loc
df.loc[ df['year']<2015 , :]
# Out:
#    year  CSM_winter  CSM_spring  CSM_fall  MUL_winter  MUL_spring  MUL_fall  \
# 0  2010        39.0        40.0      50.0        45.0         NaN      61.0
# 1  2011        48.0        44.0       NaN        58.0        52.0       NaN
# 2  2012        51.0        43.0      49.0        57.0        58.0      53.0
# 3  2013        42.0        46.0      38.0        60.0        58.0      62.0
# 4  2014        38.0        43.0      45.0        49.0        52.0      57.0
#
#    SDW_winter  SDW_spring  SDW_fall  TJE_winter  TJE_spring  TJE_fall
# 0         NaN        75.0      85.0         NaN         NaN      81.0
# 1        78.0        74.0       NaN        67.0        70.0       NaN
# 2        71.0        72.0      73.0        70.0        63.0      69.0
# 3        69.0        70.0      70.0        69.0        74.0      64.0
# 4        61.0        78.0      71.0        60.0        81.0      62.0

# %%
df[ (df['CSM_winter']>50) | (df['CSM_fall']>50)]
# Out:
#     year  CSM_winter  CSM_spring  CSM_fall  MUL_winter  MUL_spring  MUL_fall  \
# 2   2012        51.0        43.0      49.0        57.0        58.0      53.0
# 11  2021        47.0        44.0      53.0        54.0        55.0      60.0
# 13  2023        56.0        43.0      36.0        72.0        59.0      53.0
#
#     SDW_winter  SDW_spring  SDW_fall  TJE_winter  TJE_spring  TJE_fall
# 2         71.0        72.0      73.0        70.0        63.0      69.0
# 11        57.0        58.0      57.0        53.0        68.0      51.0
# 13        64.0        63.0      33.0        60.0        56.0      38.0

# %%
df[ (df['CSM_spring']>60) & (df['SDW_spring']>60)]
# Out:
# Empty DataFrame
# Columns: [year, CSM_winter, CSM_spring, CSM_fall, MUL_winter, MUL_spring, MUL_fall, SDW_winter, SDW_spring, SDW_fall, TJE_winter, TJE_spring, TJE_fall]
# Index: []

# %%
 df.iloc[6]
# Out:
# year          2016.0
# CSM_winter      41.0
# CSM_spring      36.0
# CSM_fall        47.0
# MUL_winter      63.0
# MUL_spring      48.0
# MUL_fall        58.0
# SDW_winter      67.0
# SDW_spring      62.0
# SDW_fall        57.0
# TJE_winter      76.0
# TJE_spring      76.0
# TJE_fall        58.0
# Name: 6, dtype: float64

# %%
# Select the fifth row (index=4)
df.iloc[4]
# Out:
# year          2014.0
# CSM_winter      38.0
# CSM_spring      43.0
# CSM_fall        45.0
# MUL_winter      49.0
# MUL_spring      52.0
# MUL_fall        57.0
# SDW_winter      61.0
# SDW_spring      78.0
# SDW_fall        71.0
# TJE_winter      60.0
# TJE_spring      81.0
# TJE_fall        62.0
# Name: 4, dtype: float64

# %%
# Select rows 9 through 13, inclduing 13
df.iloc[9:14]
# Out:
#     year  CSM_winter  CSM_spring  CSM_fall  MUL_winter  MUL_spring  MUL_fall  \
# 9   2019        39.0        39.0      40.0        57.0        52.0      53.0
# 10  2020        46.0         NaN      47.0        56.0         NaN      66.0
# 11  2021        47.0        44.0      53.0        54.0        55.0      60.0
# 12  2022        40.0        46.0      49.0        60.0        55.0      65.0
# 13  2023        56.0        43.0      36.0        72.0        59.0      53.0
#
#     SDW_winter  SDW_spring  SDW_fall  TJE_winter  TJE_spring  TJE_fall
# 9         54.0        55.0      53.0        63.0        54.0      50.0
# 10        57.0         NaN      58.0        54.0        40.0      54.0
# 11        57.0        58.0      57.0        53.0        68.0      51.0
# 12        57.0        60.0      57.0        60.0        61.0      60.0
# 13        64.0        63.0      33.0        60.0        56.0      38.0

# %%
df.loc[ df['year']<2020, ['MUL_fall','TJE_fall']]
# Out:
#    MUL_fall  TJE_fall
# 0      61.0      81.0
# 1       NaN       NaN
# 2      53.0      69.0
# 3      62.0      64.0
# 4      57.0      62.0
# 5      51.0      64.0
# 6      58.0      58.0
# 7      53.0      57.0
# 8      57.0      55.0
# 9      53.0      50.0

# %%
df.loc[df['year']>2020, ['MUL_winter','TJE_winter']]
# Out:
#     MUL_winter  TJE_winter
# 11        54.0        53.0
# 12        60.0        60.0
# 13        72.0        60.0

# %%
df.iloc[ 4:5 , [5,7]]
# Out:
#    MUL_spring  SDW_winter
# 4        52.0        61.0

# %%
df.iloc[3:8, [3,4]]
# Out:
#    CSM_fall  MUL_winter
# 3      38.0        60.0
# 4      45.0        49.0
# 5      45.0        58.0
# 6      47.0        63.0
# 7      43.0        57.0
